# %% [markdown]
# ## Debugging Import Issues
# Check if the `models` directory and `linear_regression.py` file exist.

# %%
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
print('Parent directory:', parent_dir)
print('Contents:', os.listdir(parent_dir))
models_path = os.path.join(parent_dir, 'models')
print('Models directory exists:', os.path.isdir(models_path))
print('linear_regression.py exists:', os.path.isfile(os.path.join(models_path, 'linear_regression.py')))
# Out:
# sys.path: ['c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch\\python311.zip', 'c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch\\DLLs', 'c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch\\Lib', 'c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch', '', 'c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch\\Lib\\site-packages', 'c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch\\Lib\\site-packages\\win32', 'c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\Shiva\\anaconda\\envs\\ml_scratch\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\Shiva\\OneDrive\\ML_from_stratch', 'c:\\Users\\Shiva\\OneDrive\\ML_from_stratch', 'c:\\Users\\Shiva\\OneDrive\\ML_from_stratch', 'c:\\Users\\Shiva\\OneDrive\\ML_from_stratch', 'c:\\Users\\Shiva\\OneDrive\\ML_from_stratch', 'c:\\Users\\Shiva\\OneDrive\\ML_from_stratch']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 7
# ...

# %%
import os
print('Current working directory:', os.getcwd())

# %%
try:
    import sys
    parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
    if parent_dir not in sys.path:
        sys.path.append(parent_dir)
    from models.linear_regression import LinearRegressionScratch
    print('Import successful!')
except Exception as e:
    print('Import failed:', e)

# %% [markdown]
# ## Setup Python Path for Imports
# Ensure the parent directory is in `sys.path` so you can import from the `models` package.

# %%
import sys, os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)
print('sys.path:', sys.path)
# Now try importing
from models.linear_regression import LinearRegressionScratch
